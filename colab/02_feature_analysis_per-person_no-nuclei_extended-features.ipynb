# %% [markdown]
# ## Data Loading

# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.5.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/gdrive/Shareddrives/CzechBioImaging-DA-Parez/2024-11-28-16-10_image_analysis_results_new-features.csv")
path_4_png='/content/gdrive/Shareddrives/CzechBioImaging-DA-Parez'

# %%
df.head()
# Out:
#    area_mean_channel1  area_std_channel1  area_min_channel1  \
# 0           64.462822          46.422859               18.0
# 1           63.054645          30.658015               16.0
# 2           56.068027          30.519526               18.0
# 3           74.182720          63.436632               21.0
# 4           70.056478         112.868410               20.0
#
#    area_max_channel1  area_median_channel1  area_count_channel1  \
# 0              952.0                  60.0                  659
# 1              374.0                  58.0                  915
# 2              579.0                  52.0                  882
# 3             1359.0                  66.0                  706
# 4             2745.0                  61.0                  602
#
#    perimeter_mean_channel1  perimeter_std_channel1  perimeter_min_channel1  \
# 0                28.219148                8.993605               12.828427
# 1                27.793966                7.502584               12.242641
# 2                26.170010                7.268740               12.828427
# 3                30.069519               10.520863               14.242641
# 4                28.802127               11.260386               13.656854
#
#    perimeter_max_channel1  ...  quartiles-2_median_channel2  \
# 0              138.509668  ...                     4142.500
# 1               76.526912  ...                     3675.250
# 2              101.254834  ...                     2812.500
# 3              191.350288  ...                     6817.500
# 4              246.048773  ...                     4611.625
#
#    quartiles-2_count_channel2  nuclei_under_membrane  \
# 0                          26                     54
# 1                          29                     41
# 2                           5                     39
# 3                           2                     62
# 4                           2                     45
#
#    percentage_nuclei_pixels  membrane_pixel_count  median_thickness  \
# 0                 10.051552                 49597         21.656571
# 1                  4.450992                 30018         18.299235
# 2                  4.606487                 34297         14.450304
# 3                  7.383576                 29064        100.013345
# 4                  5.282876                 23698         88.433326
#
#    min_thickness  max_thickness  membrane_brightness_std_dev  \
# 0       2.523133     113.411930                  2703.419076
# 1       1.954410     144.185489                  3048.226180
# 2      10.645108     205.396005                  2910.350612
# 3       7.817640     192.209049                  2722.132301
# 4       3.191538     173.675113                  2672.365620
#
#                    image_name
# 0    Healthy16_Loricrin_1.tif
# 1    Healthy16_Loricrin_2.tif
# 2    Healthy16_Loricrin_3.tif
# 3  Healthy16_Involucrin_2.tif
# 4  Healthy16_Involucrin_3.tif
#
# [5 rows x 164 columns]

# %%
def assign_type(image_name):
  if "Filaggrin" in image_name:
    return "Filaggrin"
  elif "Loricrin" in image_name:
    return "Loricrin"
  elif "Involucrin" in image_name:
    return "Involucrin"
  else:
    return "Other"

def assign_imageID(image_name):
  if "1" in image_name:
    return "1"
  elif "2" in image_name:
    return "2"
  elif "3" in image_name:
    return "3"
  else:
    return "Other"

def assign_source(image_name):
  if "Healthy" in image_name:
    return "Healthy"
  elif "P" in image_name:
    return "Patient"
  else:
    return "Other"

df["type"] = df["image_name"].apply(assign_type)
df["image-ID"] = df["image_name"].apply(assign_imageID)
df["source"] = df["image_name"].apply(assign_source)
df['person-ID'] = df['image_name'].str.split('_').str[0]

# %%
df.tail()
# Out:
#      area_mean_channel1  area_std_channel1  area_min_channel1  \
# 436          112.458711          52.590343               19.0
# 437          108.773854         200.569154               18.0
# 438          116.148043          72.810190               20.0
# 439          111.900404          90.246388               23.0
# 440          122.287544         260.511870               20.0
#
#      area_max_channel1  area_median_channel1  area_count_channel1  \
# 436              780.0                 107.0                 1877
# 437             5975.0                  92.0                 1331
# 438             1172.0                 102.0                 1763
# 439             1338.0                  97.0                  743
# 440             7901.0                 108.0                 1718
#
#      perimeter_mean_channel1  perimeter_std_channel1  perimeter_min_channel1  \
# 436                37.281679                9.403917               13.656854
# 437                35.675326               13.506635               14.485281
# 438                37.548991               11.162757               14.242641
# 439                36.620320               11.687578               16.899495
# 440                38.108445               15.805866               14.656854
#
#      perimeter_max_channel1  ...  membrane_pixel_count  median_thickness  \
# 436              103.254834  ...                129566         14.183506
# 437              322.190909  ...                135084         10.846018
# 438              140.953319  ...                  4338         35.593560
# 439              140.953319  ...                 17629         29.618610
# 440              430.593975  ...                  8749         18.746043
#
#      min_thickness  max_thickness  membrane_brightness_std_dev  \
# 436       1.128379     398.356203                  2468.993118
# 437       3.191538     309.019362                  2251.670689
# 438      18.779972      51.238852                  2825.542068
# 439       7.569398      73.335966                  2644.586269
# 440       9.836982      78.623012                  2366.818102
#
#                 image_name        type  image-ID   source  person-ID
# 436  Px58_Involucrin_3.tif  Involucrin         3  Patient       Px58
# 437  Px58_Involucrin_1.tif  Involucrin         1  Patient       Px58
# 438   Px58_Filaggrin_1.tif   Filaggrin         1  Patient       Px58
# 439   Px58_Filaggrin_3.tif   Filaggrin         3  Patient       Px58
# 440   Px58_Filaggrin_2.tif   Filaggrin         2  Patient       Px58
#
# [5 rows x 168 columns]

# %%
# Group data by 'person-ID' and 'type', then calculate the mean of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns
mean_df = df.groupby(['person-ID', 'type'])[numerical_cols].mean().reset_index()

# Display the resulting DataFrame
mean_df

# Pivot the table to have 'type' as columns
pivot_df = mean_df.pivot(index='person-ID', columns='type', values=numerical_cols)

# Flatten the MultiIndex columns
pivot_df.columns = ['_'.join(col).strip() for col in pivot_df.columns.values]

# Reset the index to make 'person-ID' a regular column
pivot_df = pivot_df.reset_index()

# Display the resulting DataFrame
pivot_df
# Out:
#     person-ID  area_mean_channel1_Filaggrin  area_mean_channel1_Involucrin  \
# 0    Healthy1                     68.674096                      77.652882
# 1   Healthy11                     58.398055                      59.755361
# 2   Healthy13                     54.430427                      56.877380
# 3   Healthy14                     65.865558                      69.207173
# 4   Healthy15                     62.633620                      60.009477
# 5   Healthy16                     61.195165                      69.889609
# 6   Healthy17                     66.432578                      64.996830
# 7   Healthy18                     50.361168                      53.309679
# 8    Healthy2                     68.680490                      51.895862
# 9   Healthy21                     64.744009                      54.616800
# 10  Healthy22                     64.117324                      59.158343
# 11   Healthy3                     59.841310                      58.701530
# 12   Healthy5                     87.736252                      87.175513
# 13   Healthy7                     49.013520                      47.727034
# 14   Healthy9                     99.573139                     102.184406
# 15         P7                           NaN                     112.022124
# 16        Px1                     92.661377                      90.135443
# 17       Px10                    107.455886                     107.790545
# 18       Px12                    104.543077                     115.489936
# 19       Px14                     83.820706                      81.235750
# 20       Px16                    105.951126                     106.295462
# 21       Px17                     99.628765                     104.415983
# 42                            285.931962
# 43                           1508.787258
# 44                           3056.935225
# 45                           1355.457202
# 46                           2493.674509
# 47                           2352.005610
# 48                             95.893534
# 49                           2047.179919
#
# [50 rows x 490 columns]

# %%
# Insert the 'source' column into the pivot_df DataFrame
pivot_df.insert(1, 'source', df.groupby('person-ID')['source'].first().values)
pivot_df
# Out:
#     person-ID   source  area_mean_channel1_Filaggrin  \
# 0    Healthy1  Healthy                     68.674096
# 1   Healthy11  Healthy                     58.398055
# 2   Healthy13  Healthy                     54.430427
# 3   Healthy14  Healthy                     65.865558
# 4   Healthy15  Healthy                     62.633620
# 5   Healthy16  Healthy                     61.195165
# 6   Healthy17  Healthy                     66.432578
# 7   Healthy18  Healthy                     50.361168
# 8    Healthy2  Healthy                     68.680490
# 9   Healthy21  Healthy                     64.744009
# 10  Healthy22  Healthy                     64.117324
# 11   Healthy3  Healthy                     59.841310
# 12   Healthy5  Healthy                     87.736252
# 13   Healthy7  Healthy                     49.013520
# 14   Healthy9  Healthy                     99.573139
# 15         P7  Patient                           NaN
# 16        Px1  Patient                     92.661377
# 17       Px10  Patient                    107.455886
# 18       Px12  Patient                    104.543077
# 19       Px14  Patient                     83.820706
# 20       Px16  Patient                    105.951126
# 21       Px17  Patient                     99.628765
# 22       Px22  Patient                     93.625500
# 23       Px23  Patient                     76.008850
# 24       Px24  Patient                    108.444721
# 25       Px25  Patient                     85.816810
# 26       Px26  Patient                    112.504080
# 27       Px27  Patient                    100.956840
# 28       Px28  Patient                     96.571345
# 29       Px30  Patient                     90.312907
# 30       Px31  Patient                    119.572326
# 31       Px32  Patient                     92.616511
# 32       Px33  Patient                     89.452196
# 33       Px35  Patient                     93.977471
# 34        Px4  Patient                    134.062076
# 35       Px41  Patient                     84.979613
# 36       Px46  Patient                    107.492097
# 37       Px47  Patient                    130.905927
# 38       Px48  Patient                    108.542770
# 39       Px49  Patient                     95.719551
# 40        Px5  Patient                    107.921336
# 41       Px50  Patient                     80.119939
# 42       Px51  Patient                     74.722669
# 43       Px52  Patient                    103.032292
# 44       Px55  Patient                     89.310472
# 45       Px57  Patient                    105.955934
# 46       Px58  Patient                    116.778664
# 47        Px6  Patient                    117.495948
# 48        Px7  Patient                    111.185252
# 49        Px8  Patient                     96.568529
#
#     area_mean_channel1_Involucrin  area_mean_channel1_Loricrin  \
# 0                       77.652882                    68.674096
# 1                       59.755361                    58.398055
# 2                       56.877380                    54.430427
# 3                       69.207173                    65.865558
# 4                       60.009477                    62.633620
# 5                       69.889609                    61.195165
# 6                       64.996830                    66.432578
# 7                       53.309679                    50.361168
# 8                       51.895862                    68.680490
# 9                       54.616800                    64.744009
# 10                      59.158343                    64.117324
# 11                      58.701530                    59.841310
# 12                      87.175513                    87.736252
# 13                      47.727034                    49.013520
# 14                     102.184406                    99.573139
# 15                     112.022124                          NaN
# 16                      90.135443                    92.661377
# 17                     107.790545                   107.455886
# 18                     115.489936                   104.543077
# 19                      81.235750                    83.820706
# 20                     106.295462                   105.951126
# 21                     104.415983                    99.628765
# 22                      96.552885                    93.625500
# 40                             2564.920498
# 41                             1698.333343
# 42                             2455.910009
# 43                             2340.307059
# 44                             2618.771423
# 45                              766.601471
# 46                             2387.162544
# 47                             2432.650592
# 48                                     NaN
# 49                              331.887993
#
#     membrane_brightness_std_dev_Loricrin
# 0                            1798.273169
# 1                            2061.187135
# 2                             998.305261
# 3                            3066.974163
# 4                            2885.347015
# 5                            2887.331956
# 6                            3242.172696
# 7                             162.578440
# 8                            2835.245109
# 9                             151.471536
# 10                           2453.271440
# 11                           3162.031953
# 12                           2139.738491
# 13                             80.582004
# 14                           2592.525164
# 15                                   NaN
# 16                           1077.622103
# 17                           1013.310903
# 18                           2099.974469
# 19                            439.420932
# 20                            576.034418
# 21                            256.426557
# 22                           2355.559352
# 23                            984.114545
# 24                           2793.821376
# 25                            652.944500
# 26                            492.154554
# 27                           1398.214670
# 28                           1611.739313
# 29                           2772.725103
# 30                           2160.856743
# 31                           1422.870451
# 32                           1660.402909
# 33                           1506.442985
# 34                           1821.231386
# 35                            711.967940
# 36                            475.666488
# 37                            318.600221
# 38                           2857.281892
# 39                           2689.250944
# 40                           1754.779791
# 41                           2938.716214
# 42                            285.931962
# 43                           1508.787258
# 44                           3056.935225
# 45                           1355.457202
# 46                           2493.674509
# 47                           2352.005610
# 48                             95.893534
# 49                           2047.179919
#
# [50 rows x 491 columns]

# %%
for column in pivot_df.columns:
  print(column)
# Out:
# person-ID
# source
# area_mean_channel1_Filaggrin
# area_mean_channel1_Involucrin
# area_mean_channel1_Loricrin
# area_std_channel1_Filaggrin
# area_std_channel1_Involucrin
# area_std_channel1_Loricrin
# area_min_channel1_Filaggrin
# area_min_channel1_Involucrin
# area_min_channel1_Loricrin
# area_max_channel1_Filaggrin
# area_max_channel1_Involucrin
# area_max_channel1_Loricrin
# area_median_channel1_Filaggrin
# area_median_channel1_Involucrin
# area_median_channel1_Loricrin
# area_count_channel1_Filaggrin
# area_count_channel1_Involucrin
# area_count_channel1_Loricrin
# perimeter_mean_channel1_Filaggrin
# perimeter_mean_channel1_Involucrin
# perimeter_mean_channel1_Loricrin
# perimeter_std_channel1_Filaggrin
# perimeter_std_channel1_Involucrin
# perimeter_std_channel1_Loricrin
# perimeter_min_channel1_Filaggrin
# perimeter_min_channel1_Involucrin
# perimeter_min_channel1_Loricrin
# perimeter_max_channel1_Filaggrin
# perimeter_max_channel1_Involucrin
# perimeter_max_channel1_Loricrin
# perimeter_median_channel1_Filaggrin
# perimeter_median_channel1_Involucrin
# perimeter_median_channel1_Loricrin
# perimeter_count_channel1_Filaggrin
# perimeter_count_channel1_Involucrin
# perimeter_count_channel1_Loricrin
# solidity_mean_channel1_Filaggrin
# solidity_mean_channel1_Involucrin
# solidity_mean_channel1_Loricrin
# solidity_std_channel1_Filaggrin
# solidity_std_channel1_Involucrin
# solidity_std_channel1_Loricrin
# solidity_min_channel1_Filaggrin
# solidity_min_channel1_Involucrin
# solidity_min_channel1_Loricrin
# solidity_max_channel1_Filaggrin
# solidity_max_channel1_Involucrin
# solidity_max_channel1_Loricrin
# solidity_median_channel1_Filaggrin
# solidity_median_channel1_Involucrin
# solidity_median_channel1_Loricrin
# solidity_count_channel1_Filaggrin
# solidity_count_channel1_Involucrin
# solidity_count_channel1_Loricrin
# max_intensity_mean_Filaggrin
# max_intensity_mean_Involucrin
# max_intensity_mean_Loricrin
# max_intensity_std_Filaggrin
# max_intensity_std_Involucrin
# max_intensity_std_Loricrin
# max_intensity_min_Filaggrin
# max_intensity_min_Involucrin
# max_intensity_min_Loricrin
# max_intensity_max_Filaggrin
# max_intensity_max_Involucrin
# max_intensity_max_Loricrin
# max_intensity_median_Filaggrin
# max_intensity_median_Involucrin
# max_intensity_median_Loricrin
# max_intensity_count_Filaggrin
# max_intensity_count_Involucrin
# max_intensity_count_Loricrin
# mean_intensity_mean_channel1_Filaggrin
# mean_intensity_mean_channel1_Involucrin
# mean_intensity_mean_channel1_Loricrin
# mean_intensity_std_channel1_Filaggrin
# mean_intensity_std_channel1_Involucrin
# mean_intensity_std_channel1_Loricrin
# mean_intensity_min_channel1_Filaggrin
# mean_intensity_min_channel1_Involucrin
# mean_intensity_min_channel1_Loricrin
# mean_intensity_max_channel1_Filaggrin
# mean_intensity_max_channel1_Involucrin
# mean_intensity_max_channel1_Loricrin
# mean_intensity_median_channel1_Filaggrin
# mean_intensity_median_channel1_Involucrin
# mean_intensity_median_channel1_Loricrin
# mean_intensity_count_channel1_Filaggrin
# mean_intensity_count_channel1_Involucrin
# mean_intensity_count_channel1_Loricrin
# min_intensity_mean_Filaggrin
# min_intensity_mean_Involucrin
# min_intensity_mean_Loricrin
# min_intensity_std_Filaggrin
# min_intensity_std_Involucrin
# min_intensity_std_Loricrin
# min_intensity_min_Filaggrin
# min_intensity_min_Involucrin
# min_intensity_min_Loricrin
# min_intensity_max_Filaggrin
# min_intensity_max_Involucrin
# min_intensity_max_Loricrin
# min_intensity_median_Filaggrin
# min_intensity_median_Involucrin
# min_intensity_median_Loricrin
# min_intensity_count_Filaggrin
# min_intensity_count_Involucrin
# min_intensity_count_Loricrin
# major_axis_length_mean_channel1_Filaggrin
# major_axis_length_mean_channel1_Involucrin
# major_axis_length_mean_channel1_Loricrin
# major_axis_length_std_channel1_Filaggrin
# major_axis_length_std_channel1_Involucrin
# major_axis_length_std_channel1_Loricrin
# major_axis_length_min_channel1_Filaggrin
# major_axis_length_min_channel1_Involucrin
# major_axis_length_min_channel1_Loricrin
# major_axis_length_max_channel1_Filaggrin
# major_axis_length_max_channel1_Involucrin
# major_axis_length_max_channel1_Loricrin
# major_axis_length_median_channel1_Filaggrin
# major_axis_length_median_channel1_Involucrin
# major_axis_length_median_channel1_Loricrin
# major_axis_length_count_channel1_Filaggrin
# major_axis_length_count_channel1_Involucrin
# major_axis_length_count_channel1_Loricrin
# minor_axis_length_mean_channel1_Filaggrin
# minor_axis_length_mean_channel1_Involucrin
# minor_axis_length_mean_channel1_Loricrin
# minor_axis_length_std_channel1_Filaggrin
# minor_axis_length_std_channel1_Involucrin
# minor_axis_length_std_channel1_Loricrin
# minor_axis_length_min_channel1_Filaggrin
# minor_axis_length_min_channel1_Involucrin
# minor_axis_length_min_channel1_Loricrin
# minor_axis_length_max_channel1_Filaggrin
# minor_axis_length_max_channel1_Involucrin
# minor_axis_length_max_channel1_Loricrin
# minor_axis_length_median_channel1_Filaggrin
# minor_axis_length_median_channel1_Involucrin
# minor_axis_length_median_channel1_Loricrin
# minor_axis_length_count_channel1_Filaggrin
# minor_axis_length_count_channel1_Involucrin
# minor_axis_length_count_channel1_Loricrin
# quartiles-0_mean_channel1_Filaggrin
# quartiles-0_mean_channel1_Involucrin
# quartiles-0_mean_channel1_Loricrin
# quartiles-0_std_channel1_Filaggrin
# quartiles-0_std_channel1_Involucrin
# quartiles-0_std_channel1_Loricrin
# quartiles-0_min_channel1_Filaggrin
# quartiles-0_min_channel1_Involucrin
# quartiles-0_min_channel1_Loricrin
# quartiles-0_max_channel1_Filaggrin
# quartiles-0_max_channel1_Involucrin
# quartiles-0_max_channel1_Loricrin
# quartiles-0_median_channel1_Filaggrin
# quartiles-0_median_channel1_Involucrin
# quartiles-0_median_channel1_Loricrin
# quartiles-0_count_channel1_Filaggrin
# quartiles-0_count_channel1_Involucrin
# quartiles-0_count_channel1_Loricrin
# quartiles-1_mean_channel1_Filaggrin
# quartiles-1_mean_channel1_Involucrin
# quartiles-1_mean_channel1_Loricrin
# quartiles-1_std_channel1_Filaggrin
# quartiles-1_std_channel1_Involucrin
# quartiles-1_std_channel1_Loricrin
# quartiles-1_min_channel1_Filaggrin
# quartiles-1_min_channel1_Involucrin
# quartiles-1_min_channel1_Loricrin
# quartiles-1_max_channel1_Filaggrin
# quartiles-1_max_channel1_Involucrin
# quartiles-1_max_channel1_Loricrin
# quartiles-1_median_channel1_Filaggrin
# quartiles-1_median_channel1_Involucrin
# quartiles-1_median_channel1_Loricrin
# quartiles-1_count_channel1_Filaggrin
# quartiles-1_count_channel1_Involucrin
# quartiles-1_count_channel1_Loricrin
# quartiles-2_mean_channel1_Filaggrin
# quartiles-2_mean_channel1_Involucrin
# quartiles-2_mean_channel1_Loricrin
# quartiles-2_std_channel1_Filaggrin
# quartiles-2_std_channel1_Involucrin
# quartiles-2_std_channel1_Loricrin
# quartiles-2_min_channel1_Filaggrin
# quartiles-2_min_channel1_Involucrin
# quartiles-2_min_channel1_Loricrin
# quartiles-2_max_channel1_Filaggrin
# quartiles-2_max_channel1_Involucrin
# quartiles-2_max_channel1_Loricrin
# quartiles-2_median_channel1_Filaggrin
# quartiles-2_median_channel1_Involucrin
# quartiles-2_median_channel1_Loricrin
# quartiles-2_count_channel1_Filaggrin
# quartiles-2_count_channel1_Involucrin
# quartiles-2_count_channel1_Loricrin
# area_mean_channel2_Filaggrin
# area_mean_channel2_Involucrin
# area_mean_channel2_Loricrin
# area_std_channel2_Filaggrin
# area_std_channel2_Involucrin
# area_std_channel2_Loricrin
# area_min_channel2_Filaggrin
# area_min_channel2_Involucrin
# area_min_channel2_Loricrin
# area_max_channel2_Filaggrin
# area_max_channel2_Involucrin
# area_max_channel2_Loricrin
# area_median_channel2_Filaggrin
# area_median_channel2_Involucrin
# area_median_channel2_Loricrin
# area_count_channel2_Filaggrin
# area_count_channel2_Involucrin
# area_count_channel2_Loricrin
# perimeter_mean_channel2_Filaggrin
# perimeter_mean_channel2_Involucrin
# perimeter_mean_channel2_Loricrin
# perimeter_std_channel2_Filaggrin
# perimeter_std_channel2_Involucrin
# perimeter_std_channel2_Loricrin
# perimeter_min_channel2_Filaggrin
# perimeter_min_channel2_Involucrin
# perimeter_min_channel2_Loricrin
# perimeter_max_channel2_Filaggrin
# perimeter_max_channel2_Involucrin
# perimeter_max_channel2_Loricrin
# perimeter_median_channel2_Filaggrin
# perimeter_median_channel2_Involucrin
# perimeter_median_channel2_Loricrin
# perimeter_count_channel2_Filaggrin
# perimeter_count_channel2_Involucrin
# perimeter_count_channel2_Loricrin
# centroid-0_mean_Filaggrin
# centroid-0_mean_Involucrin
# centroid-0_mean_Loricrin
# centroid-0_std_Filaggrin
# centroid-0_std_Involucrin
# centroid-0_std_Loricrin
# centroid-0_min_Filaggrin
# centroid-0_min_Involucrin
# centroid-0_min_Loricrin
# centroid-0_max_Filaggrin
# centroid-0_max_Involucrin
# centroid-0_max_Loricrin
# centroid-0_median_Filaggrin
# centroid-0_median_Involucrin
# centroid-0_median_Loricrin
# centroid-0_count_Filaggrin
# centroid-0_count_Involucrin
# centroid-0_count_Loricrin
# centroid-1_mean_Filaggrin
# centroid-1_mean_Involucrin
# centroid-1_mean_Loricrin
# centroid-1_std_Filaggrin
# centroid-1_std_Involucrin
# centroid-1_std_Loricrin
# centroid-1_min_Filaggrin
# centroid-1_min_Involucrin
# centroid-1_min_Loricrin
# centroid-1_max_Filaggrin
# centroid-1_max_Involucrin
# centroid-1_max_Loricrin
# centroid-1_median_Filaggrin
# centroid-1_median_Involucrin
# centroid-1_median_Loricrin
# centroid-1_count_Filaggrin
# centroid-1_count_Involucrin
# centroid-1_count_Loricrin
# bbox-0_mean_Filaggrin
# bbox-0_mean_Involucrin
# bbox-0_mean_Loricrin
# bbox-0_std_Filaggrin
# bbox-0_std_Involucrin
# bbox-0_std_Loricrin
# bbox-0_min_Filaggrin
# bbox-0_min_Involucrin
# bbox-0_min_Loricrin
# bbox-0_max_Filaggrin
# bbox-0_max_Involucrin
# bbox-0_max_Loricrin
# bbox-0_median_Filaggrin
# bbox-0_median_Involucrin
# bbox-0_median_Loricrin
# bbox-0_count_Filaggrin
# bbox-0_count_Involucrin
# bbox-0_count_Loricrin
# bbox-1_mean_Filaggrin
# bbox-1_mean_Involucrin
# bbox-1_mean_Loricrin
# bbox-1_std_Filaggrin
# bbox-1_std_Involucrin
# bbox-1_std_Loricrin
# bbox-1_min_Filaggrin
# bbox-1_min_Involucrin
# bbox-1_min_Loricrin
# bbox-1_max_Filaggrin
# bbox-1_max_Involucrin
# bbox-1_max_Loricrin
# bbox-1_median_Filaggrin
# bbox-1_median_Involucrin
# bbox-1_median_Loricrin
# bbox-1_count_Filaggrin
# bbox-1_count_Involucrin
# bbox-1_count_Loricrin
# bbox-2_mean_Filaggrin
# bbox-2_mean_Involucrin
# bbox-2_mean_Loricrin
# bbox-2_std_Filaggrin
# bbox-2_std_Involucrin
# bbox-2_std_Loricrin
# bbox-2_min_Filaggrin
# bbox-2_min_Involucrin
# bbox-2_min_Loricrin
# bbox-2_max_Filaggrin
# bbox-2_max_Involucrin
# bbox-2_max_Loricrin
# bbox-2_median_Filaggrin
# bbox-2_median_Involucrin
# bbox-2_median_Loricrin
# bbox-2_count_Filaggrin
# bbox-2_count_Involucrin
# bbox-2_count_Loricrin
# bbox-3_mean_Filaggrin
# bbox-3_mean_Involucrin
# bbox-3_mean_Loricrin
# bbox-3_std_Filaggrin
# bbox-3_std_Involucrin
# bbox-3_std_Loricrin
# bbox-3_min_Filaggrin
# bbox-3_min_Involucrin
# bbox-3_min_Loricrin
# bbox-3_max_Filaggrin
# bbox-3_max_Involucrin
# bbox-3_max_Loricrin
# bbox-3_median_Filaggrin
# bbox-3_median_Involucrin
# bbox-3_median_Loricrin
# bbox-3_count_Filaggrin
# bbox-3_count_Involucrin
# bbox-3_count_Loricrin
# solidity_mean_channel2_Filaggrin
# solidity_mean_channel2_Involucrin
# solidity_mean_channel2_Loricrin
# solidity_std_channel2_Filaggrin
# solidity_std_channel2_Involucrin
# solidity_std_channel2_Loricrin
# solidity_min_channel2_Filaggrin
# solidity_min_channel2_Involucrin
# solidity_min_channel2_Loricrin
# solidity_max_channel2_Filaggrin
# solidity_max_channel2_Involucrin
# solidity_max_channel2_Loricrin
# solidity_median_channel2_Filaggrin
# solidity_median_channel2_Involucrin
# solidity_median_channel2_Loricrin
# solidity_count_channel2_Filaggrin
# solidity_count_channel2_Involucrin
# solidity_count_channel2_Loricrin
# mean_intensity_mean_channel2_Filaggrin
# mean_intensity_mean_channel2_Involucrin
# mean_intensity_mean_channel2_Loricrin
# mean_intensity_std_channel2_Filaggrin
# mean_intensity_std_channel2_Involucrin
# mean_intensity_std_channel2_Loricrin
# mean_intensity_min_channel2_Filaggrin
# mean_intensity_min_channel2_Involucrin
# mean_intensity_min_channel2_Loricrin
# mean_intensity_max_channel2_Filaggrin
# mean_intensity_max_channel2_Involucrin
# mean_intensity_max_channel2_Loricrin
# mean_intensity_median_channel2_Filaggrin
# mean_intensity_median_channel2_Involucrin
# mean_intensity_median_channel2_Loricrin
# mean_intensity_count_channel2_Filaggrin
# mean_intensity_count_channel2_Involucrin
# mean_intensity_count_channel2_Loricrin
# major_axis_length_mean_channel2_Filaggrin
# major_axis_length_mean_channel2_Involucrin
# major_axis_length_mean_channel2_Loricrin
# major_axis_length_std_channel2_Filaggrin
# major_axis_length_std_channel2_Involucrin
# major_axis_length_std_channel2_Loricrin
# major_axis_length_min_channel2_Filaggrin
# major_axis_length_min_channel2_Involucrin
# major_axis_length_min_channel2_Loricrin
# major_axis_length_max_channel2_Filaggrin
# major_axis_length_max_channel2_Involucrin
# major_axis_length_max_channel2_Loricrin
# major_axis_length_median_channel2_Filaggrin
# major_axis_length_median_channel2_Involucrin
# major_axis_length_median_channel2_Loricrin
# major_axis_length_count_channel2_Filaggrin
# major_axis_length_count_channel2_Involucrin
# major_axis_length_count_channel2_Loricrin
# minor_axis_length_mean_channel2_Filaggrin
# minor_axis_length_mean_channel2_Involucrin
# minor_axis_length_mean_channel2_Loricrin
# minor_axis_length_std_channel2_Filaggrin
# minor_axis_length_std_channel2_Involucrin
# minor_axis_length_std_channel2_Loricrin
# minor_axis_length_min_channel2_Filaggrin
# minor_axis_length_min_channel2_Involucrin
# minor_axis_length_min_channel2_Loricrin
# minor_axis_length_max_channel2_Filaggrin
# minor_axis_length_max_channel2_Involucrin
# minor_axis_length_max_channel2_Loricrin
# minor_axis_length_median_channel2_Filaggrin
# minor_axis_length_median_channel2_Involucrin
# minor_axis_length_median_channel2_Loricrin
# minor_axis_length_count_channel2_Filaggrin
# minor_axis_length_count_channel2_Involucrin
# minor_axis_length_count_channel2_Loricrin
# quartiles-0_mean_channel2_Filaggrin
# quartiles-0_mean_channel2_Involucrin
# quartiles-0_mean_channel2_Loricrin
# quartiles-0_std_channel2_Filaggrin
# quartiles-0_std_channel2_Involucrin
# quartiles-0_std_channel2_Loricrin
# quartiles-0_min_channel2_Filaggrin
# quartiles-0_min_channel2_Involucrin
# quartiles-0_min_channel2_Loricrin
# quartiles-0_max_channel2_Filaggrin
# quartiles-0_max_channel2_Involucrin
# quartiles-0_max_channel2_Loricrin
# quartiles-0_median_channel2_Filaggrin
# quartiles-0_median_channel2_Involucrin
# quartiles-0_median_channel2_Loricrin
# quartiles-0_count_channel2_Filaggrin
# quartiles-0_count_channel2_Involucrin
# quartiles-0_count_channel2_Loricrin
# quartiles-1_mean_channel2_Filaggrin
# quartiles-1_mean_channel2_Involucrin
# quartiles-1_mean_channel2_Loricrin
# quartiles-1_std_channel2_Filaggrin
# quartiles-1_std_channel2_Involucrin
# quartiles-1_std_channel2_Loricrin
# quartiles-1_min_channel2_Filaggrin
# quartiles-1_min_channel2_Involucrin
# quartiles-1_min_channel2_Loricrin
# quartiles-1_max_channel2_Filaggrin
# quartiles-1_max_channel2_Involucrin
# quartiles-1_max_channel2_Loricrin
# quartiles-1_median_channel2_Filaggrin
# quartiles-1_median_channel2_Involucrin
# quartiles-1_median_channel2_Loricrin
# quartiles-1_count_channel2_Filaggrin
# quartiles-1_count_channel2_Involucrin
# quartiles-1_count_channel2_Loricrin
# quartiles-2_mean_channel2_Filaggrin
# quartiles-2_mean_channel2_Involucrin
# quartiles-2_mean_channel2_Loricrin
# quartiles-2_std_channel2_Filaggrin
# quartiles-2_std_channel2_Involucrin
# quartiles-2_std_channel2_Loricrin
# quartiles-2_min_channel2_Filaggrin
# quartiles-2_min_channel2_Involucrin
# quartiles-2_min_channel2_Loricrin
# quartiles-2_max_channel2_Filaggrin
# quartiles-2_max_channel2_Involucrin
# quartiles-2_max_channel2_Loricrin
# quartiles-2_median_channel2_Filaggrin
# quartiles-2_median_channel2_Involucrin
# quartiles-2_median_channel2_Loricrin
# quartiles-2_count_channel2_Filaggrin
# quartiles-2_count_channel2_Involucrin
# quartiles-2_count_channel2_Loricrin
# nuclei_under_membrane_Filaggrin
# nuclei_under_membrane_Involucrin
# nuclei_under_membrane_Loricrin
# percentage_nuclei_pixels_Filaggrin
# percentage_nuclei_pixels_Involucrin
# percentage_nuclei_pixels_Loricrin
# membrane_pixel_count_Filaggrin
# membrane_pixel_count_Involucrin
# membrane_pixel_count_Loricrin
# median_thickness_Filaggrin
# median_thickness_Involucrin
# median_thickness_Loricrin
# min_thickness_Filaggrin
# min_thickness_Involucrin
# min_thickness_Loricrin
# max_thickness_Filaggrin
# max_thickness_Involucrin
# max_thickness_Loricrin
# membrane_brightness_std_dev_Filaggrin
# membrane_brightness_std_dev_Involucrin
# membrane_brightness_std_dev_Loricrin

# %%
# prompt: I want to drop any columns containing name _channel1_Filaggrin and _channel1_Loricrin

# Drop columns containing specific substrings
# columns_to_drop = [col for col in pivot_df.columns if '_channel1_Involucrin' in col]# or '_channel1_Loricrin' in col]
columns_to_drop = [col for col in pivot_df.columns if '_channel1_Involucrin' in col or '_channel1_Loricrin' in col or '_channel1_Filaggrin' in col]
pivot_df = pivot_df.drop(columns=columns_to_drop)
pivot_df
path_4_png=''

# %%
# @title
import umap
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# def do_the_thing_UMAP(df,input_type,path_4_png):
# Select Type
# if input_type == 'Loricrin':
#   df_type = df[df['type'] == input_type]
# elif input_type == 'Filaggrin':
#   df_type = df[df['type'] == input_type]
# elif input_type == 'Involucrin':
#   df_type = df[df['type'] == input_type]
# else: #all
#   df_type = df#[df['type'] == input_type]

input_type='All-Combined'

df_type = pivot_df

# Correlation analysis
correlation_matrix = df_type.iloc[:, 2:].corr()

# Select the x most unique features based on variance (you can use other metrics as well)
# variances = df_type.iloc[:, 3:].var()
variances = correlation_matrix.var()
most_unique_features = variances.nlargest(505).index #.nsmallest(25).index

# Create a new dataframe with the selected features
new_df = df_type[['person-ID','source'] + list(most_unique_features)]
# Drop rows with NaN values in the specified columns
new_df = new_df.dropna(subset=list(most_unique_features))

new_df
# Out:
#     person-ID   source  solidity_mean_channel2_Loricrin  \
# 0    Healthy1  Healthy                         0.845777
# 1   Healthy11  Healthy                         0.816416
# 2   Healthy13  Healthy                         0.835670
# 3   Healthy14  Healthy                         0.826288
# 4   Healthy15  Healthy                         0.814201
# 5   Healthy16  Healthy                         0.832958
# 7   Healthy18  Healthy                         0.911563
# 8    Healthy2  Healthy                         0.756734
# 9   Healthy21  Healthy                         0.906829
# 10  Healthy22  Healthy                         0.695561
# 11   Healthy3  Healthy                         0.789915
# 12   Healthy5  Healthy                         0.847702
# 13   Healthy7  Healthy                         0.888021
# 14   Healthy9  Healthy                         0.803944
# 16        Px1  Patient                         0.899679
# 17       Px10  Patient                         0.917952
# 18       Px12  Patient                         0.730740
# 19       Px14  Patient                         0.877700
# 20       Px16  Patient                         0.759875
# 21       Px17  Patient                         0.911489
# 22       Px22  Patient                         0.688209
# 23       Px23  Patient                         0.866880
# 24       Px24  Patient                         0.747209
# 25       Px25  Patient                         0.740770
# 26       Px26  Patient                         0.886522
# 27       Px27  Patient                         0.875758
# 28       Px28  Patient                         0.677342
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Assuming 'new_df' is already defined as in the previous code

# Prepare the data for t-SNE
X = new_df.iloc[:, 2:]  # Exclude 'person-ID' and 'source' columns
source = new_df['source']

# Apply t-SNE
tsne = TSNE(n_components=2, random_state=42) # You can adjust perplexity, early_exaggeration, etc.
X_embedded = tsne.fit_transform(X)

# Create the scatter plot
plt.figure(figsize=(10, 8))
for s in source.unique():
  plt.scatter(X_embedded[source == s, 0], X_embedded[source == s, 1], label=s)
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.title("t-SNE Clustering based on Source")
plt.legend()
# plt.show()

if len(path_4_png) > 0:
  plt.savefig(f'{path_4_png}/Tsne_projection_{input_type}_source.png')
else:
  plt.savefig(f'Tsne_projection__projection_{input_type}_source.png')
plt.show()

# %%
# prompt: use umap cluster based on source column

# Assuming the previous code is executed and 'new_df' is available

import umap

# Create a UMAP reducer with specified parameters
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)

# Fit and transform the data using the selected features, excluding 'person-ID' and 'source'
embedding = reducer.fit_transform(new_df.iloc[:, 2:])

# Create a new DataFrame with the embedding results
embedding_df = pd.DataFrame(embedding, columns=['UMAP1', 'UMAP2'])

# Concatenate the embedding results with 'person-ID' and 'source'
embedding_df = pd.concat([new_df[['person-ID', 'source']], embedding_df], axis=1)

# Now you can use the 'embedding_df' for visualization or further analysis
# For example, plot the UMAP embedding colored by 'source':
plt.figure(figsize=(10, 8))
sns.scatterplot(x='UMAP1', y='UMAP2', hue='source', data=embedding_df)
plt.title('UMAP Embedding Colored by Source')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
#Use UMAP to cluster features in df_new

# Select the feature columns
# feature_cols = most_unique_features
feature_cols = new_df.columns[2:]
X = new_df[feature_cols].values


# Apply UMAP
# reducer = umap.UMAP(n_neighbors=7, min_dist=0.5, random_state=42) # Adjust parameters as needed
reducer = umap.UMAP(n_neighbors=35, min_dist=0.15, random_state=42) # Adjust parameters as needed
embedding = reducer.fit_transform(X)

# Add UMAP coordinates to the DataFrame
new_df['umap_x'] = embedding[:, 0]
new_df['umap_y'] = embedding[:, 1]



# Now you can use df_new['umap_x'] and df_new['umap_y'] for plotting or further analysis

# Example plot (optional)
plt.scatter(new_df['umap_x'], new_df['umap_y'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# path_4_png=''

# Create the scatter plot with different symbols based on the 'source' column
plt.figure(figsize=(8, 6))

for source in new_df['source'].unique():
    subset = new_df[new_df['source'] == source]
    plt.scatter(subset['umap_x'], subset['umap_y'], label=source, alpha=0.7)

plt.xlabel('UMAP X')
plt.ylabel('UMAP Y')
plt.title(f'UMAP Projection of {input_type} Data Colored by Source')
plt.legend()
plt.grid(True)
if len(path_4_png) > 0:
  plt.savefig(f'{path_4_png}/umap_projection_{input_type}_source.png')
  print(f'{path_4_png}/umap_projection_{input_type}_source.png')
else:
  plt.savefig(f'umap_projection_{input_type}_source.png')
plt.show()

# %%
# Now you can use df_new['umap_x'] and df_new['umap_y'] for plotting or further analysis

# Example plot (optional)
plt.scatter(new_df[most_unique_features[0]], new_df[most_unique_features[1]])
plt.show()

# Create the scatter plot with different symbols based on the 'source' column
plt.figure(figsize=(8, 6))

for source in new_df['source'].unique():
    subset = new_df[new_df['source'] == source]
    plt.scatter(subset[most_unique_features[0]], subset[most_unique_features[1]], label=source, alpha=0.7)

plt.xlabel(most_unique_features[0])
plt.ylabel(most_unique_features[1])
plt.title(f'var Projection of {input_type} Data Colored by Source')
plt.legend()
plt.grid(True)
if len(path_4_png) > 0:
  plt.savefig(f'{path_4_png}/var_projection_{input_type}_source.png')
else:
  plt.savefig(f'var_projection_{input_type}_source.png')
plt.show()

# %%
# prompt: do a PCA analysis and explain first 5 most meaningful features

import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming 'new_df' and 'most_unique_features' are defined from the previous code

# Select numerical features for PCA
features = new_df[most_unique_features]#.dropna()

# Scale the data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Apply PCA
pca = PCA(n_components=5)  # Reduce to 5 principal components
pca_result = pca.fit_transform(scaled_features)

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'])

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Print explained variance for each principal component
print("Explained variance ratio for each principal component:")
for i, ratio in enumerate(explained_variance_ratio):
  print(f"PC{i+1}: {ratio:.4f}")


# Analyze loadings to interpret principal components
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5'], index=most_unique_features)

# Print the top 5 features with highest absolute loading for each component
for i in range(5):  # Iterate through each PC
  print(f"\nTop 5 features for PC{i+1}:")
  top_features = loadings.iloc[:,i].abs().nlargest(5).index
  for feature in top_features:
      print(f"{feature}: {loadings.loc[feature,f'PC{i+1}']:.4f}")
# Out:
# Explained variance ratio for each principal component:
# PC1: 0.1754
# PC2: 0.1243
# PC3: 0.1006
# PC4: 0.0710
# PC5: 0.0619
#
# Top 5 features for PC1:
# mean_intensity_min_channel2_Loricrin: 0.1079
# quartiles-2_min_channel2_Loricrin: 0.1068
# mean_intensity_median_channel2_Loricrin: 0.1043
# mean_intensity_mean_channel2_Loricrin: 0.1042
# quartiles-1_min_channel2_Loricrin: 0.1041
#
# Top 5 features for PC2:
# quartiles-2_min_channel2_Involucrin: 0.1301
# major_axis_length_std_channel2_Involucrin: 0.1288
# mean_intensity_min_channel2_Involucrin: 0.1253
# major_axis_length_mean_channel2_Involucrin: 0.1227
# quartiles-1_min_channel2_Involucrin: 0.1216
#
# Top 5 features for PC3:
# quartiles-0_max_channel2_Involucrin: 0.1134
# mean_intensity_std_channel2_Involucrin: 0.1094
# max_thickness_Involucrin: 0.1071
# quartiles-1_std_channel2_Involucrin: 0.1040
# mean_intensity_max_channel2_Involucrin: 0.1027
#
# Top 5 features for PC4:
# min_intensity_median_Loricrin: 0.1467
# min_intensity_median_Filaggrin: 0.1467
# min_intensity_mean_Loricrin: 0.1447
# min_intensity_mean_Filaggrin: 0.1447
# bbox-2_std_Involucrin: -0.1211
#
# Top 5 features for PC5:
# major_axis_length_min_channel2_Filaggrin: 0.1486
# major_axis_length_median_channel2_Filaggrin: 0.1479
# perimeter_min_channel2_Filaggrin: 0.1456
# area_min_channel2_Filaggrin: 0.1395
# perimeter_median_channel2_Filaggrin: 0.1372

# %%
# Select numerical features for PCA
features = new_df[most_unique_features]#.dropna()

# Scale the data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Apply PCA
pca = PCA(n_components=2)  # Reduce to 5 principal components
pca_result = pca.fit_transform(scaled_features)

# Create a DataFrame with the PCA results
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Print explained variance for each principal component
print("Explained variance ratio for each principal component:")
for i, ratio in enumerate(explained_variance_ratio):
  print(f"PC{i+1}: {ratio:.4f}")


# Analyze loadings to interpret principal components
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2'], index=most_unique_features)

# Print the top 5 features with highest absolute loading for each component
for i in range(2):  # Iterate through each PC
  print(f"\nTop 2 features for PC{i+1}:")
  top_features = loadings.iloc[:,i].abs().nlargest(5).index
  for feature in top_features:
      print(f"{feature}: {loadings.loc[feature,f'PC{i+1}']:.4f}")
# Out:
# Explained variance ratio for each principal component:
# PC1: 0.1754
# PC2: 0.1243
#
# Top 2 features for PC1:
# mean_intensity_min_channel2_Loricrin: 0.1079
# quartiles-2_min_channel2_Loricrin: 0.1068
# mean_intensity_median_channel2_Loricrin: 0.1043
# mean_intensity_mean_channel2_Loricrin: 0.1042
# quartiles-1_min_channel2_Loricrin: 0.1041
#
# Top 2 features for PC2:
# quartiles-2_min_channel2_Involucrin: 0.1301
# major_axis_length_std_channel2_Involucrin: 0.1288
# mean_intensity_min_channel2_Involucrin: 0.1253
# major_axis_length_mean_channel2_Involucrin: 0.1227
# quartiles-1_min_channel2_Involucrin: 0.1216

# %% [markdown]
# ## Explained variance ratio for each principal component:
# PC1: 0.2054
# PC2: 0.1178
# PC3: 0.1005
# PC4: 0.0666
# PC5: 0.0573
#
# ### Top 5 features for PC1:
#  * minor_axis_length_mean_channel1_Loricrin: 0.0903
#  * minor_axis_length_mean_channel1_Filaggrin: 0.0903
#  * minor_axis_length_median_channel1_Loricrin: 0.0900
#  * minor_axis_length_median_channel1_Filaggrin: 0.0900
#  * solidity_median_channel1_Filaggrin: 0.0899
#
# ### Top 5 features for PC2:
#  * solidity_std_channel2_Loricrin: 0.0950
#  * major_axis_length_mean_channel2_Loricrin: 0.0911
#  * solidity_mean_channel2_Loricrin: -0.0910
#  * solidity_mean_channel2_Filaggrin: -0.0882
#  * major_axis_length_mean_channel2_Involucrin: 0.0876
#
# ### Top 5 features for PC3:
#  * centroid-0_count_Loricrin: 0.0985
#  * perimeter_count_channel2_Loricrin: 0.0985
#  * bbox-3_count_Loricrin: 0.0985
#  * bbox-0_count_Loricrin: 0.0985
#  * area_count_channel2_Loricrin: 0.0985
#
# ### Top 5 features for PC4:
#  * min_intensity_mean_Filaggrin: 0.1102
#  * min_intensity_mean_Loricrin: 0.1102
#  * min_intensity_median_Loricrin: 0.1099
#  * min_intensity_median_Filaggrin: 0.1099
#  * quartiles-1_max_channel2_Involucrin: 0.0928
#
# ### Top 5 features for PC5:
#  * quartiles-0_mean_channel1_Involucrin: 0.1338
#  * quartiles-0_median_channel1_Involucrin: 0.1332
#  * quartiles-1_median_channel1_Involucrin: 0.1260
#  * quartiles-1_mean_channel1_Involucrin: 0.1255
#  * mean_intensity_mean_channel1_Involucrin: 0.1254

# %%
new_df = new_df.reset_index(drop=True)

# %%
# Select numerical features for PCA
# features = new_df[most_unique_features]#.dropna()

# # Apply PCA with 2 components for visualization
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(features)

# Create a DataFrame for the PCA results
# pca_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
pca_df = pca_df[['PC1', 'PC2']]
pca_df['source'] = new_df['source']


# Plot the PCA results
plt.figure(figsize=(8, 6))
for source in pca_df['source'].unique():
    subset = pca_df[pca_df['source'] == source]
    plt.scatter(subset['PC1'], subset['PC2'], label=source, alpha=0.7)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Projection of Data Colored by Source')
plt.legend()
plt.grid(True)

if len(path_4_png) > 0:
  plt.savefig(f'{path_4_png}/PCA_projection_{input_type}_source.png')
  print(f'{path_4_png}/PCA_projection_{input_type}_source.png')
else:
  plt.savefig(f'PCA_projection_{input_type}_source.png')
plt.show()
# Out:
# <ipython-input-41-9a69d68e2b5e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pca_df['source'] = new_df['source']

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-6fcf9dfbd479> in <cell line: 1>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## Details

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only one Type
df_fillagrin = df[df['type'] == 'Loricrin']

# Correlation analysis
correlation_matrix = df_fillagrin.iloc[:, :-4].corr()

# %%
for column in correlation_matrix.columns:
  print(column)

# %%
# Plot the correlation matrix using seaborn
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Features for Filaggrin')
plt.show()

# %%
# Select the 5 most unique features based on variance (you can use other metrics as well)
# variances = df_fillagrin.iloc[:, 3:].var()
variances = correlation_matrix.var()
most_unique_features = variances.nlargest(55).index #.nsmallest(25).index

# Create a new dataframe with the selected features
new_df = df_fillagrin[['source','image-ID', 'type', 'image_name'] + list(most_unique_features)]

new_df.head()

# %%
most_unique_features

# %%
# Drop rows with NaN values in the specified columns
new_df = new_df.dropna(subset=list(most_unique_features))

# %%
#Use UMAP to cluster features in df_new

import umap
import pandas as pd


# Select the feature columns
feature_cols = most_unique_features
X = new_df[feature_cols].values


# Apply UMAP
reducer = umap.UMAP(n_neighbors=7, min_dist=0.5, random_state=42) # Adjust parameters as needed
embedding = reducer.fit_transform(X)

# Add UMAP coordinates to the DataFrame
new_df['umap_x'] = embedding[:, 0]
new_df['umap_y'] = embedding[:, 1]

# Now you can use df_new['umap_x'] and df_new['umap_y'] for plotting or further analysis

# Example plot (optional)
plt.scatter(new_df['umap_x'], new_df['umap_y'])
plt.show()

# %%
# prompt: plot scatter plot of umap_x and umap_y with different symbols based on source column

import matplotlib.pyplot as plt

# Create the scatter plot with different symbols based on the 'source' column
plt.figure(figsize=(8, 6))

for source in new_df['source'].unique():
    subset = new_df[new_df['source'] == source]
    plt.scatter(subset['umap_x'], subset['umap_y'], label=source, alpha=0.7)

plt.xlabel('UMAP X')
plt.ylabel('UMAP Y')
plt.title('UMAP Projection of Filaggrin Data Colored by Source')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create the scatter plot with different symbols based on the 'source' column
plt.figure(figsize=(8, 6))

for source in new_df['type'].unique():
    subset = new_df[new_df['type'] == source]
    plt.scatter(subset['umap_x'], subset['umap_y'], label=source, alpha=0.7)

plt.xlabel('UMAP X')
plt.ylabel('UMAP Y')
plt.title('UMAP Projection of Filaggrin Data Colored by Type')
plt.legend()
plt.grid(True)
plt.show()
